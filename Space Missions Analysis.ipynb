# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv("../Dataset/Space_Corrected.csv")

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 9 columns]

# %% [markdown]
# # Data Preparation

# %%
df = df.drop('Unnamed: 0.1',axis=1)
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %% [markdown]
# ### Identify missing values to handle it

# %%
df.dtypes
# Out:
# Company Name      object
# Location          object
# Datum             object
# Detail            object
# Status Rocket     object
#  Rocket           object
# Status Mission    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Company Name         0
# Location             0
# Datum                0
# Detail               0
# Status Rocket        0
#  Rocket           3360
# Status Mission       0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive       0
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired       0
# 4320                           Juno I | Explorer 1  StatusRetired       0
# 4321                       Vanguard | Vanguard TV3  StatusRetired       0
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired       0
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired       0
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %% [markdown]
# ### Checking columns for change if needed

# %%
df.columns
# Out:
# Index(['Company Name', 'Location', 'Datum', 'Detail', 'Status Rocket',
#        ' Rocket', 'Status Mission'],
#       dtype='object')

# %%
f = df.Datum
f
# Out:
# 0       Fri Aug 07, 2020 05:12 UTC
# 1       Thu Aug 06, 2020 04:01 UTC
# 2       Tue Aug 04, 2020 23:57 UTC
# 3       Thu Jul 30, 2020 21:25 UTC
# 4       Thu Jul 30, 2020 11:50 UTC
#                    ...
# 4319    Wed Feb 05, 1958 07:33 UTC
# 4320    Sat Feb 01, 1958 03:48 UTC
# 4321    Fri Dec 06, 1957 16:44 UTC
# 4322    Sun Nov 03, 1957 02:30 UTC
# 4323    Fri Oct 04, 1957 19:28 UTC
# Name: Datum, Length: 4324, dtype: object

# %%
df = df.rename(columns={' Rocket':'rrocket'})

# %%
df.rrocket = df.rrocket.fillna(0)

# %%
df.rrocket.unique()
# Out:
# array(['50.0 ', '29.75 ', 0, '65.0 ', '145.0 ', '64.68 ', '48.5 ',
#        '90.0 ', '46.0 ', '28.3 ', '29.15 ', '7.5 ', '30.8 ', '5.3 ',
#        '12.0 ', '112.5 ', '120.0 ', '153.0 ', '200.0 ', '85.0 ', '115.0 ',
#        '41.8 ', '21.0 ', '31.0 ', '40.0 ', '164.0 ', '62.0 ', '37.0 ',
#        '350.0 ', '39.0 ', '47.0 ', '35.0 ', '69.7 ', '109.0 ', '45.0 ',
#        '123.0 ', '130.0 ', '25.0 ', '56.5 ', '15.0 ', '29.0 ', '80.0 ',
#        '140.0 ', '55.0 ', '59.5 ', '450.0 ', '7.0 ', '20.14 ', '133.0 ',
#        '190.0 ', '135.0 ', '20.0 ', '136.6 ', '5,000.0 ', '1,160.0 ',
#        '59.0 ', '63.23 '], dtype=object)

# %% [markdown]
# ### change the columns in their usual names

# %%
df = df.rename(columns={'Detail':'rocket'})

# %%
df = df.rename(columns={'rrocket':'price'})

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             rocket  Status Rocket   price  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive       0
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired       0
# 4320                           Juno I | Explorer 1  StatusRetired       0
# 4321                       Vanguard | Vanguard TV3  StatusRetired       0
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired       0
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired       0
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %% [markdown]
# ### checking for dtype of the column

# %%
df.price.unique()
# Out:
# array(['50.0 ', '29.75 ', 0, '65.0 ', '145.0 ', '64.68 ', '48.5 ',
#        '90.0 ', '46.0 ', '28.3 ', '29.15 ', '7.5 ', '30.8 ', '5.3 ',
#        '12.0 ', '112.5 ', '120.0 ', '153.0 ', '200.0 ', '85.0 ', '115.0 ',
#        '41.8 ', '21.0 ', '31.0 ', '40.0 ', '164.0 ', '62.0 ', '37.0 ',
#        '350.0 ', '39.0 ', '47.0 ', '35.0 ', '69.7 ', '109.0 ', '45.0 ',
#        '123.0 ', '130.0 ', '25.0 ', '56.5 ', '15.0 ', '29.0 ', '80.0 ',
#        '140.0 ', '55.0 ', '59.5 ', '450.0 ', '7.0 ', '20.14 ', '133.0 ',
#        '190.0 ', '135.0 ', '20.0 ', '136.6 ', '5,000.0 ', '1,160.0 ',
#        '59.0 ', '63.23 '], dtype=object)

# %%
df.price = df.price.replace('[,]','',regex=True).astype('float64')

# %%
df.price.unique()
# Out:
# array([  50.  ,   29.75,    0.  ,   65.  ,  145.  ,   64.68,   48.5 ,
#          90.  ,   46.  ,   28.3 ,   29.15,    7.5 ,   30.8 ,    5.3 ,
#          12.  ,  112.5 ,  120.  ,  153.  ,  200.  ,   85.  ,  115.  ,
#          41.8 ,   21.  ,   31.  ,   40.  ,  164.  ,   62.  ,   37.  ,
#         350.  ,   39.  ,   47.  ,   35.  ,   69.7 ,  109.  ,   45.  ,
#         123.  ,  130.  ,   25.  ,   56.5 ,   15.  ,   29.  ,   80.  ,
#         140.  ,   55.  ,   59.5 ,  450.  ,    7.  ,   20.14,  133.  ,
#         190.  ,  135.  ,   20.  ,  136.6 , 5000.  , 1160.  ,   59.  ,
#          63.23])

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %% [markdown]
# ### What is the distribution of numerical features such as mission cost and launch year?

# %%
df.describe()
# Out:
#              price
# count  4324.000000
# mean     34.286698
# std     150.442829
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max    5000.000000

# %%
df.Datum.unique()
# Out:
# array(['Fri Aug 07, 2020 05:12 UTC', 'Thu Aug 06, 2020 04:01 UTC',
#        'Tue Aug 04, 2020 23:57 UTC', ..., 'Fri Dec 06, 1957 16:44 UTC',
#        'Sun Nov 03, 1957 02:30 UTC', 'Fri Oct 04, 1957 19:28 UTC'],
#       dtype=object)

# %%
df.price.unique()
# Out:
# array([  50.  ,   29.75,    0.  ,   65.  ,  145.  ,   64.68,   48.5 ,
#          90.  ,   46.  ,   28.3 ,   29.15,    7.5 ,   30.8 ,    5.3 ,
#          12.  ,  112.5 ,  120.  ,  153.  ,  200.  ,   85.  ,  115.  ,
#          41.8 ,   21.  ,   31.  ,   40.  ,  164.  ,   62.  ,   37.  ,
#         350.  ,   39.  ,   47.  ,   35.  ,   69.7 ,  109.  ,   45.  ,
#         123.  ,  130.  ,   25.  ,   56.5 ,   15.  ,   29.  ,   80.  ,
#         140.  ,   55.  ,   59.5 ,  450.  ,    7.  ,   20.14,  133.  ,
#         190.  ,  135.  ,   20.  ,  136.6 , 5000.  , 1160.  ,   59.  ,
#          63.23])

# %%
df.price.fillna(0)
# Out:
# 0        50.00
# 1        29.75
# 2         0.00
# 3        65.00
# 4       145.00
#          ...
# 4319      0.00
# 4320      0.00
# 4321      0.00
# 4322      0.00
# 4323      0.00
# Name: price, Length: 4324, dtype: float64

# %% [markdown]
# # Top Agencies Analysis

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# MHI                   84
# Northrop              83
# Lockheed              79
# ISRO                  76
# Roscosmos             55
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Kosmotras             22
# US Navy               17
# ISA                   13
# Rocket Lab            13
# Eurockot              13
# ESA                   13
# Blue Origin           12
# IAI                   11
# ExPace                10
# ASI                    9
# CNES                   8
# AMBA                   8
# MITT                   7
# JAXA                   7
# Land Launch            7
# UT                     5
# KCST                   5
# CASIC                  5
# Exos                   4
# CECLES                 4
# Arm??e de l'Air        4
# KARI                   3
# SRC                    3
# AEB                    3
# RAE                    2
# OKB-586                2
# Yuzhmash               2
# Landspace              1
# Douglas                1
# EER                    1
# Starsem                1
# Virgin Orbit           1
# IRGC                   1
# i-Space                1
# OneSpace               1
# Sandia                 1
# Khrunichev             1
# Name: count, dtype: int64

# %% [markdown]
# ### Rocket and status analysis

# %%
df.rocket.value_counts()
# Out:
# rocket
# Cosmos-3MRB (65MRB) | BOR-5 Shuttle    6
# Lambda-IV S | Osumi                    5
# Titan IV(402)B | DSP                   5
# Titan IIID | KH-11                     5
# Proton K/Block D | Zond                4
#                                       ..
# Ariane 44P | Intelsat 709              1
# Ariane 5 G | Cluster                   1
# Delta II 7925 | Galaxy 9               1
# Space Shuttle Endeavour | STS-77       1
# Sputnik 8K71PS | Sputnik-1             1
# Name: count, Length: 4278, dtype: int64

# %%
sb.histplot(data=df, x='price', hue='Status Mission', palette='flare', kde=True)
plt.title('Cost Distribution Analysis', fontsize=14, fontweight='bold')
plt.show()

# %%
sb.boxplot(df.price)
plt.title('Top Launch Locations', fontsize=14, fontweight='bold')
plt.show()

# %%
df[df['Status Mission'] == 'Success'].groupby('Company Name').size()
# Out:
# Company Name
# AMBA                   4
# ASI                    9
# Arianespace          269
# Arm??e de l'Air        3
# Blue Origin           12
# Boeing               131
# CASC                 231
# CASIC                  3
# CECLES                 1
# CNES                   6
# Douglas                1
# ESA                    9
# Eurockot              12
# ExPace                 9
# General Dynamics     203
# IAI                    9
# ILS                   45
# IRGC                   1
# ISA                    4
# ISAS                  26
# ISRO                  63
# JAXA                   6
# KARI                   1
# KCST                   2
# Khrunichev             1
# Kosmotras             21
# Land Launch            6
# Lockheed              74
# MHI                   80
# MITT                   6
# Martin Marietta      100
# NASA                 186
# Northrop              74
# OKB-586                2
# RAE                    1
# RVSN USSR           1614
# Rocket Lab            11
# Roscosmos             51
# SRC                    2
# Sea Launch            33
# SpaceX                94
# Starsem                1
# ULA                  139
# US Air Force         129
# US Navy                2
# UT                     1
# VKS RF               188
# Yuzhmash               2
# i-Space                1
# dtype: int64

# %%
df[df['Status Mission'] == 'Failure'].groupby('Company Name').size().nlargest()
# Out:
# Company Name
# RVSN USSR           121
# General Dynamics     37
# US Air Force         30
# CASC                 14
# US Navy              14
# dtype: int64

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# MHI                   84
# Northrop              83
# Lockheed              79
# ISRO                  76
# Roscosmos             55
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Kosmotras             22
# US Navy               17
# ISA                   13
# Rocket Lab            13
# Eurockot              13
# ESA                   13
# Blue Origin           12
# IAI                   11
# ExPace                10
# ASI                    9
# CNES                   8
# AMBA                   8
# MITT                   7
# JAXA                   7
# Land Launch            7
# UT                     5
# KCST                   5
# CASIC                  5
# Exos                   4
# CECLES                 4
# Arm??e de l'Air        4
# KARI                   3
# SRC                    3
# AEB                    3
# RAE                    2
# OKB-586                2
# Yuzhmash               2
# Landspace              1
# Douglas                1
# EER                    1
# Starsem                1
# Virgin Orbit           1
# IRGC                   1
# i-Space                1
# OneSpace               1
# Sandia                 1
# Khrunichev             1
# Name: count, dtype: int64

# %%
 df[df['Status Mission'] == 'Success'].groupby('Location').size()
# Out:
# Location
# Blue Origin Launch Site, West Texas, Texas, USA       12
# Brigitte, Hammaguir, Algeria, France                   3
# ELA-1, Guiana Space Centre, French Guiana, France     12
# ELA-2, Guiana Space Centre, French Guiana, France    115
# ELA-3, Guiana Space Centre, French Guiana, France    104
#                                                     ...
# Svobodny Cosmodrome, Russia                            5
# Tai Rui Barge, Yellow Sea                              1
# Taiyuan Satellite Launch Center, China                 5
# Uchinoura Space Center, Japan                          2
# Xichang Satellite Launch Center, China                 1
# Length: 128, dtype: int64

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             rocket  Status Rocket   price  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.00
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive   29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive    0.00
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.00
# 4                       Atlas V 541 | Perseverance   StatusActive  145.00
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired    0.00
# 4320                           Juno I | Explorer 1  StatusRetired    0.00
# 4321                       Vanguard | Vanguard TV3  StatusRetired    0.00
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired    0.00
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired    0.00
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %% [markdown]
# # Launch Site Analysis

# %% [markdown]
# ### What are the top locations used for launches?

# %%
c = df['rocket'].value_counts().nlargest(10)
c
# Out:
# rocket
# Cosmos-3MRB (65MRB) | BOR-5 Shuttle         6
# Lambda-IV S | Osumi                         5
# Titan IV(402)B | DSP                        5
# Titan IIID | KH-11                          5
# Proton K/Block D | Zond                     4
# Cosmos-3MRB (65MRB) | BOR-2 Shuttle         4
# Titan IIID | KH-9                           4
# Safir-1B+ | Unknown Payload                 3
# Cosmos-3M (11K65M) | Strela-2M satellite    3
# Cosmos-3MRB (65MRB) | BOR-4 Shuttle         3
# Name: count, dtype: int64

# %%
g=df['Location'].value_counts().nlargest(10)

plt.figure(figsize=(10,5))
sb.barplot(x=g.index, y=g.values, color='#FFDAB9') 
plt.xlabel('Launch Location', fontsize=12)
plt.ylabel('Number of Launches', fontsize=12)
plt.title('Top Launch Locations', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### This chart above shows the location wise launches per year

# %%
plt.figure(figsize=(10,5))
sb.barplot(x=c.index,y=c.values,color = '#CDECF6')
plt.xticks(rotation =90)
plt.xlabel('Launch Location', fontsize=12)
plt.ylabel('Number of Launches', fontsize=12)
plt.title('Top Launch Locations', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ### How many successful space missions has each company conducted?

# %%
df[['Company Name', 'price']].groupby('Company Name').mean()
# Out:
#                        price
# Company Name
# AEB                 0.000000
# AMBA                0.000000
# ASI                 0.000000
# Arianespace        58.584229
# Arm??e de l'Air     0.000000
# Blue Origin         0.000000
# Boeing              9.125000
# CASC               25.260000
# CASIC               0.000000
# CECLES              0.000000
# CNES                0.000000
# Douglas             0.000000
# EER                20.000000
# ESA                 2.846154
# Eurockot           41.800000
# ExPace              2.830000
# Exos                0.000000
# General Dynamics    0.000000
# IAI                 0.000000
# ILS                28.695652
# IRGC                0.000000
# ISA                 0.000000
# ISAS                0.000000
# ISRO               28.644737
# JAXA               24.000000
# KARI                0.000000
# KCST                0.000000
# Khrunichev          0.000000
# Kosmotras          29.000000
# Land Launch         0.000000
# Landspace           0.000000
# Lockheed            3.544304
# MHI                42.053571
# MITT                0.000000
# Martin Marietta     6.328070
# NASA              375.763547
# Northrop           47.349398
# OKB-586             0.000000
# OneSpace            0.000000
# RAE                 0.000000
# RVSN USSR           5.627462
# Rocket Lab          7.500000
# Roscosmos          21.590909
# SRC                 0.000000
# Sandia             15.000000
# Sea Launch          0.000000
# SpaceX             54.440000
# Starsem             0.000000
# ULA               105.700000
# US Air Force        9.633043
# US Navy             0.000000
# UT                  0.000000
# VKS RF              7.705970
# Virgin Orbit       12.000000
# Yuzhmash            0.000000
# i-Space             0.000000

# %%
df.price.astype('int64')
# Out:
# 0        50
# 1        29
# 2         0
# 3        65
# 4       145
#        ...
# 4319      0
# 4320      0
# 4321      0
# 4322      0
# 4323      0
# Name: price, Length: 4324, dtype: int64

# %% [markdown]
# ### This is to check the datatype of the year

# %%
df[df['Status Mission']== 'Success']['price'].mean()
# Out:
# 36.9609538540861

# %%
df[df['Status Mission']== 'Failure']['price'].mean()
# Out:
# 7.153215339233038

# %% [markdown]
# #### Extracting the data of month in month and year in year

# %%
df['month'] = df.Datum.str[4:7]

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             rocket  Status Rocket   price  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.00
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive   29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive    0.00
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.00
# 4                       Atlas V 541 | Perseverance   StatusActive  145.00
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired    0.00
# 4320                           Juno I | Explorer 1  StatusRetired    0.00
# 4321                       Vanguard | Vanguard TV3  StatusRetired    0.00
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired    0.00
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired    0.00
#
#      Status Mission month
# 0           Success   Aug
# 1           Success   Aug
# 2           Success   Aug
# 3           Success   Jul
# 4           Success   Jul
# ...             ...   ...
# 4319        Failure   Feb
# 4320        Success   Feb
# 4321        Failure   Dec
# 4322        Success   Nov
# 4323        Success   Oct
#
# [4324 rows x 8 columns]

# %%
df['year'] = df.Datum.str[11:16]

# %%
df.year.astype('int64')
# Out:
# 0       2020
# 1       2020
# 2       2020
# 3       2020
# 4       2020
#         ...
# 4319    1958
# 4320    1958
# 4321    1957
# 4322    1957
# 4323    1957
# Name: year, Length: 4324, dtype: int64

# %%
df.month.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### This is to extract the datatype of the object

# %%
 df[df['Status Mission'] == 'Success']['price'].mean()
# Out:
# 36.9609538540861

# %%
 z = df['year'].value_counts().sort_index()

# %%
plt.figure(figsize=(20,8))
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Launches', fontsize=12)
plt.title('No.of Launches', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
sb.lineplot(x=z.index,y=z.values)
plt.show()

# %% [markdown]
# ### The above graph shows the no. of launches per year form the year 1957 to year 2020

# %% [markdown]
# # Rocket ans Status Analysis:

# %% [markdown]
# ### Which rockets are used most frequently?

# %% [markdown]
# ### The rockets most frequently are used are listed below

# %%
t=df.rocket.value_counts().nlargest(10)
plt.figure(figsize=(10,5))
sb.barplot(x=t.index, y=t.values, color = '#D8BFD8')  
plt.xlabel('Rocket Name', fontsize=12)
plt.ylabel('Number of Launches', fontsize=12)
plt.title('Most Frequently Used Rockets', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### The rocket Cosmos-3MRB (65MRB) | BOR-5 Shuttle is the one most used rocket for the launch

# %% [markdown]
# ### Which rockets are used most frequently?

# %%
df['Status Rocket'].value_counts()
# Out:
# Status Rocket
# StatusRetired    3534
# StatusActive      790
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sb.countplot(x=df['Status Rocket'],color='#D8BFD8') 
plt.xlabel('Status Rocket', fontsize=12)
plt.ylabel('Number of Rockets', fontsize=12)
plt.title('Active vs Inactive Rockets', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Cost Analysis

# %% [markdown]
# ### Which companies spend the most?

# %%
s= df.groupby("Company Name")["price"].mean().nlargest(10)

plt.figure(figsize=(10,5))
sb.barplot(x=s.index, y=s.values,color = '#B8F2E6') 
plt.xlabel('Organisation', fontsize=12)
plt.ylabel('Total Spend ($)', fontsize=12)
plt.title('Companies with Highest Spending', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Which rockets are the most expensive?

# %%
e= df.groupby("rocket")["price"].sum().nlargest(10)

plt.figure(figsize=(10,5))
sb.barplot(x=e.index, y=e.values)
plt.xlabel('Rocket Name', fontsize=12)
plt.ylabel('Price ($)', fontsize=12)
plt.title('Most Expensive Rockets', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Temporal Analysis

# %% [markdown]
# ### How has the number of space launches changed over the Years?

# %%
df.year.unique().astype('int64')
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010,
#        2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999,
#        1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988,
#        1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977,
#        1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966,
#        1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958, 1957], dtype=int64)

# %%
a2=df.groupby(['year','Status Mission']).size().reset_index()
a2
# Out:
#       year     Status Mission    0
# 0     1957            Failure    1
# 1     1957            Success    2
# 2     1958            Failure   20
# 3     1958    Partial Failure    2
# 4     1958            Success    6
# ..     ...                ...  ...
# 173   2019    Partial Failure    2
# 174   2019  Prelaunch Failure    1
# 175   2019            Success  100
# 176   2020            Failure    6
# 177   2020            Success   57
#
# [178 rows x 3 columns]

# %%
plt.figure(figsize=(20,8))
sb.barplot(x=a2.year,y=a2[0],hue=a2['Status Mission'])
plt.xticks(rotation=90)
plt.legend(title='Mission Status',bbox_to_anchor=(1.0,1.0))
plt.show()

# %% [markdown]
# ### The graph shows the noticable outcomes over the years
